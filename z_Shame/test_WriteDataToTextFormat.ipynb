# %%
import requests
import json
import pandas as pd
# url = "https://www.chattadata.org/resource/cged-2r5q.json"
# url = "https://www.chattadata.org/resource/t8ph-y8y5.json"
# url = "https://www.chattadata.org/resource/4qjh-fdm6.json"
# url = "https://www.chattadata.org/resource/4qjh-fdm6.json"
url = "https://www.chattadata.org/resource/krpq-4iht.json"
noAuthResp = requests.get(url)
noAuthResp.raise_for_status()
noAuthData = noAuthResp.json()
noAuthData
# Out:
# [{'gislink': '033127H A 02100',
#   'ownername1': 'BROWN KARLY RAE',
#   'propstnum': '1808',
#   'propstname': 'WHITE OAK',
#   'propsfx': 'RD',
#   'map': '127H',
#   'group': 'A',
#   'parcel': '021',
#   'taxmapnumber': '127H A 021',
#   'mailstname': '1808 WHITE OAK RD',
#   'mailcity': 'CHATTANOOGA',
#   'mailstate': 'TN',
#   'mailzip': '37415',
#   'legaldesc': 'LT 5 BLK H DALLAS HEIGHTS RESUB REV PB 27 PG 182',
#   'calcacres': '1',
#   'lucode': '111',
#   'neighborhoodcode': '1',
#   'landvalue': '88200',
#   'buildingvalue': '86900',
#   'appraisedvalue': '175100',
#   'assessedvalue': '43775',
#   'district': '1',
#   'zoning': 'R1',
#   'proptype': '22',
#   'plat1book': '27',
#   'plat1page': '182',
#   'plat1lot': '5',
#   'sale1year': '2016',
#   'sale1month': '02',
#   'sale1day': '12',
#   'sale1book': '10672',
#   'sale1page': '0890',
#   'sale2year': '1976',
#   'sale2month': '04',
#   'sale2day': '01',
#   'sale2book': '2315',
#   'sale2page': '0146',
# ...

# %%
# cged-2r5q -Asset Inventory View
#!/usr/bin/env python
import pandas as pd
from pandas import Series, DataFrame
from sodapy import Socrata

client = Socrata("www.chattadata.org",
                 "FCT6DKqNfDQlV4eUvvfiF1cTz",
                 username="Trey.causey@outlook.com",
                 password="Fillet#07")

# First 2000 results, returned as JSON from API / converted to Python list of
# dictionaries by sodapy.
# authResults = client.get("cged-2r5q", limit=2000)
# t8ph-y8y5
# https://www.chattadata.org/resource/bcsf-zcb7.json
# authResults = client.get("t8ph-y8y5", limit=2000)
# authResults = client.get("bcsf-zcb7", limit=2000)
# authResults = client.get("krpq-4iht", limit=100000)
authResults = client.get("fpgh-69ti", limit=10000)
# Convert to pandas DataFrame
authResults_df = pd.DataFrame.from_records(authResults)
authResults_df
# Out:
#                gislink                      ownername1 propstnum propstname  \
# 0      033127H A 02100                 BROWN KARLY RAE      1808  WHITE OAK
# 1      033065N D 03300               DALRYMPLE JEFFREY       149   MONTLAKE
# 2      033157I E 01900                  MOURIER ERIN E       203    BELVOIR
# 3      033090D A 01600           MILLER CHAD S & KAREN      6083  BROWNTOWN
# 4      033127P Q 00900         REINVENTED CONCEPTS LLC      1339     HIXSON
# ...                ...                             ...       ...        ...
# 99995  033155C C 01600                 SOUTH BROAD LLC       NaN     COWART
# 99996  033147H J 01100             HOLLAND DONALD R JR      1009   BELMEADE
# 99997  033073B B 00501                 EARLY MICHAEL R       224    HOUSLEY
# 99998  033168E A 00200  BUFFINGTON J RICHARD & NANCY J      3513     SHELBY
# 99999  033126E A 04000    ANDERSON RICHARD & GERALDINE      1623   WESTOVER
#
# ...

# %%
authResults_df.describe()
# Out:
#                 gislink     ownername1 propstnum propstname propsfx     map  \
# count             99991         100000     93489      99988   99361  100000
# unique            97384          81535     11805       5766      70    1214
# top     033117O A 01100  CHATT CITY OF         0     HIXSON      RD    146C
# freq                319            437       437        609   23500     435
#
#         group  parcel     taxmapnumber    mailstname  ... sale4type sale1type  \
# count   88269  100000           100000         99998  ...     55814     55927
# unique     25    5938            97724         74105  ...        23        23
# top         A     001  117O A 011   C3  P O BOX 4201  ...         S         W
# freq    19054    3264               72           222  ...     26601     30772
#
#        sale1conf                ownername2 exemptcode propaddrunit  \
# count      33337                     15969       3295          790
# ...

# %%
authResults_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 65 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   gislink           99991 non-null   object
#  1   ownername1        100000 non-null  object
#  2   propstnum         93489 non-null   object
#  3   propstname        99988 non-null   object
#  4   propsfx           99361 non-null   object
#  5   map               100000 non-null  object
#  6   group             88269 non-null   object
#  7   parcel            100000 non-null  object
#  8   taxmapnumber      100000 non-null  object
#  9   mailstname        99998 non-null   object
#  10  mailcity          99999 non-null   object
#  11  mailstate         99988 non-null   object
#  12  mailzip           99992 non-null   object
#  13  legaldesc         99998 non-null   object
#  14  calcacres         99544 non-null   object
#  15  lucode            99999 non-null   object
# ...
